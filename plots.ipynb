# %%
import matplotlib.pyplot as plt

# %%
def plot_loss(loss_values, title='Loss Plot'):
    plt.plot(loss_values, label='Loss')
    plt.title(title)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
loss_values = [None, 0.6301, 0.616, 0.6105, 0.6065, 0.6031, 0.5994, 0.5960, 0.5896, 0.5793, 0.5553, 0.4177, 0.3658, 0.3629, 0.3618, 0.3617]

plot_loss(loss_values, title='Loss Over Epochs')

# %%
def plot_metrics(train_values, test_values, title, metric_name):
    plt.plot(train_values, label='Train')
    plt.plot(test_values, label='Test')
    plt.title(title)
    plt.xlabel('Epoch')
    plt.ylabel(metric_name)
    plt.legend()
    plt.show()

# %%
train_accuracy = [None, 0.6079, 0.6797, 0.6942, 0.6993, 0.705, 0.7079, 0.7133, 0.7207, 0.7304, 0.7438, 0.8062, 0.9642, 0.9821, 0.9829, 0.9828]
test_accuracy = [None, 0.666, 0.689, 0.6865, 0.6924, 0.6979, 0.705, 0.7101, 0.7181, 0.7269, 0.7547, 0.9111, 0.9347, 0.9355, 0.9359, 0.9359]
plot_metrics(train_accuracy, test_accuracy, 'Accuracy Over Epochs', 'Accuracy')

# %%
train_f1 = [None, 0.5819, 0.6609, 0.6830, 0.6905, 0.697, 0.7008, 0.7063, 0.7144, 0.7244, 0.7380, 0.8017, 0.9634, 0.9817, 0.9825, 0.9824]
test_f1 = [None, 0.4373, 0.5576, 0.5768, 0.5899, 0.6067, 0.6204, 0.6394, 0.6477, 0.6593, 0.7052, 0.8907, 0.9179, 0.9188, 0.9193, 0.9193]
plot_metrics(train_f1, test_f1, 'F1 Over Epochs', 'F1')

# %%
plt.plot(train_f1, label='Train F1', color='blue')
plt.plot(test_f1, label='TestF1', color='green')
plt.plot(train_accuracy, label='Train Accuracy', color='red')
plt.plot(test_accuracy, label='Test Accuracy', color='orange')
plt.title('Accuracy and F1 Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy, F1')
plt.legend()
plt.show()

# %%
plt.plot(train_f1, label='Train F1')
plt.plot(test_f1, label='Test F1')
plt.plot(loss_values, label='Loss')
plt.title('Loss and F1 Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss, F1')
plt.legend()
plt.show()

# %%
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(test_accuracy, label='Test Accuracy')
plt.plot(loss_values, label='Loss')
plt.title('Loss and Accuarcy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss, Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(train_f1, label='Train F1', color='blue')
plt.plot(test_f1, label='TestF1', color='green')
plt.plot(train_accuracy, label='Train Accuracy', color='red')
plt.plot(test_accuracy, label='Test Accuracy', color='orange')
plt.plot(loss_values, label='Loss', color='grey')
plt.title('Accuracy, F1 and Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy, F1, Loss')
plt.legend()
plt.show()
